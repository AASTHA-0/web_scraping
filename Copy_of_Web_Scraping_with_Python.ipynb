# %% [markdown]
# *Web Scraping with Python*****#
#
# **Summary**
#
# In this notebook, we will learn about Beautiful Soup and work through some HTML examples to understand how this library works.
#
# To Learn More:
#
# Samsung Ocean lectures and courses.
# Ryan Mitchell, Web Scraping with Python: Collecting More Data from the Modern Web, Novatec Publishing, 2019.

# %% [markdown]
# 1) **BeautifulSoup**

# %%
from bs4 import BeautifulSoup

# %%
html = """
<html>
  <head>
    <title>Oscar Awards 2020</title>
  </head>
  <body>
    <h1>Oscar Awards 2020</h1>
    <p>The biggest film awards ceremony took place in February. This year's highlights were:</p>
    <p>See below the winners of 3 categories.</p>

    <div class="categoria-melhor-filme">
      <h2>Categoria: Melhor Filme</h2>
      <ul class="destaques">
        <li class="vencedor">Parasita [VENCEDOR]</li>
        <li>1917</li>
        <li>Era Uma Vez em Hollywood</li>
        <li>O Irlandês</li>
        <li>Coringa</li>
        <li>Pequenas Mulheres</li>
        <li>Casamento às Pressas</li>
        <li>Ford vs Ferrari</li>
        <li>Jojo Rabbit</li>
      </ul>
    </div>

    <div class="categoria-melhor-ator">
      <h2>Categoria: Melhor Ator</h2>
      <ul class="destaques">
        <li class="vencedor">Joaquin Phoenix - Coringa [VENCEDOR]</li>
        <li>Antonio Banderas - Dor e Glória</li>
        <li>Adam Driver - História de um Casamento</li>
        <li>Leonardo DiCaprio - Era Uma Vez em Hollywood</li>
        <li>Jonathan Pryce - Os Dois Papas</li>
      </ul>
    </div>

    <div class="categoria-melhor-atriz">
      <h2>Categoria: Melhor Atriz</h2>
      <ul class="destaques">
        <li class="vencedor">Renée Zellweger - Judy [VENCEDOR]</li>
        <li>Cynthia Erivo - Harriet</li>
        <li>Scarlett Johansson - História de um Casamento</li>
        <li>Saoirse Ronan - Pequenas Mulheres</li>
        <li>Charlize Theron - O Escândalo</li>
      </ul>
    </div>
  </body>
</html>
"""

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# <html>
# <head>
# <title>Oscar Awards 2020</title>
# </head>
# <body>
# <h1>Oscar Awards 2020</h1>
# <p>The biggest film awards ceremony took place in February. This year's highlights were:</p>
# <p>See below the winners of 3 categories.</p>
# <div class="categoria-melhor-filme">
# <h2>Categoria: Melhor Filme</h2>
# <ul class="destaques">
# <li class="vencedor">Parasita [VENCEDOR]</li>
# <li>1917</li>
# <li>Era Uma Vez em Hollywood</li>
# <li>O Irlandês</li>
# <li>Coringa</li>
# <li>Pequenas Mulheres</li>
# <li>Casamento às Pressas</li>
# <li>Ford vs Ferrari</li>
# <li>Jojo Rabbit</li>
# </ul>
# </div>
# <div class="categoria-melhor-ator">
# <h2>Categoria: Melhor Ator</h2>
# <ul class="destaques">
# <li class="vencedor">Joaquin Phoenix - Coringa [VENCEDOR]</li>
# <li>Antonio Banderas - Dor e Glória</li>
# <li>Adam Driver - História de um Casamento</li>
# <li>Leonardo DiCaprio - Era Uma Vez em Hollywood</li>
# <li>Jonathan Pryce - Os Dois Papas</li>
# </ul>
# </div>
# <div class="categoria-melhor-atriz">
# <h2>Categoria: Melhor Atriz</h2>
# <ul class="destaques">
# <li class="vencedor">Renée Zellweger - Judy [VENCEDOR]</li>
# <li>Cynthia Erivo - Harriet</li>
# <li>Scarlett Johansson - História de um Casamento</li>
# <li>Saoirse Ronan - Pequenas Mulheres</li>
# <li>Charlize Theron - O Escândalo</li>
# </ul>
# </div>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Oscar Awards 2020
#   </title>
#  </head>
#  <body>
#   <h1>
#    Oscar Awards 2020
#   </h1>
#   <p>
#    The biggest film awards ceremony took place in February. This year's highlights were:
#   </p>
#   <p>
#    See below the winners of 3 categories.
#   </p>
#   <div class="categoria-melhor-filme">
#    <h2>
#     Categoria: Melhor Filme
#    </h2>
#    <ul class="destaques">
#     <li class="vencedor">
#      Parasita [VENCEDOR]
#     </li>
#     <li>
#      1917
#     </li>
#     <li>
#      Era Uma Vez em Hollywood
#     </li>
#     <li>
#      O Irlandês
#     </li>
#     <li>
#      Coringa
#     </li>
#     <li>
#      Pequenas Mulheres
#     </li>
#     <li>
#      Casamento às Pressas
#     </li>
#     <li>
#      Ford vs Ferrari
#     </li>
#     <li>
#      Jojo Rabbit
#     </li>
#    </ul>
#   </div>
#   <div class="categoria-melhor-ator">
#    <h2>
#     Categoria: Melhor Ator
#    </h2>
#    <ul class="destaques">
#     <li class="vencedor">
#      Joaquin Phoenix - Coringa [VENCEDOR]
#     </li>
#     <li>
#      Antonio Banderas - Dor e Glória
#     </li>
#     <li>
#      Adam Driver - História de um Casamento
#     </li>
#     <li>
#      Leonardo DiCaprio - Era Uma Vez em Hollywood
#     </li>
#     <li>
#      Jonathan Pryce - Os Dois Papas
#     </li>
#    </ul>
#   </div>
#   <div class="categoria-melhor-atriz">
#    <h2>
#     Categoria: Melhor Atriz
#    </h2>
#    <ul class="destaques">
#     <li class="vencedor">
#      Renée Zellweger - Judy [VENCEDOR]
#     </li>
#     <li>
#      Cynthia Erivo - Harriet
#     </li>
#     <li>
#      Scarlett Johansson - História de um Casamento
#     </li>
#     <li>
#      Saoirse Ronan - Pequenas Mulheres
#     </li>
#     <li>
#      Charlize Theron - O Escândalo
#     </li>
#    </ul>
#   </div>
#  </body>
# </html>

# %% [markdown]
# 2) **Extracting Data from HTML Tags****

# %% [markdown]
# ### 2.1)  Getting Started: How to Extract a Web Page's Title?

# %%
soup.html.head.title
# Out:
# <title>Oscar Awards 2020</title>

# %%
soup.title
# Out:
# <title>Oscar Awards 2020</title>

# %%
soup.title.get_text()
# Out:
# 'Oscar Awards 2020'

# %% [markdown]
# ###  2.2) How Can I Extract the Main Heading from the Page?

# %%
soup.html.body.h1
# Out:
# <h1>Oscar Awards 2020</h1>

# %%
soup.h1
# Out:
# <h1>Oscar Awards 2020</h1>

# %%
soup.h1.get_text()
# Out:
# 'Oscar Awards 2020'

# %% [markdown]
# ### Question 1: Which of the commands below would NOT collect the text "Category: Best Picture"?
#
# a) soup.body.div.div.h2.get_text()
#
# b) soup.div.div.h2.get_text()
#
# c) soup.div.ul.h2.get_text()
#
# d) soup.h2.get_text()

# %% [markdown]
# ### 2.3) Collecting the Text
#
# "The biggest film awards ceremony took place in February. This year's highlights were:"

# %%
soup.p.get_text()
# Out:
# "The biggest film awards ceremony took place in February. This year's highlights were:"

# %% [markdown]
# ### But... What If I Want to Extract the Text:
#
# "See below the winners of 3 categories."

# %% [markdown]
# ### 2.4) The find() Method

# %%
soup.find("p")
# Out:
# <p>The biggest film awards ceremony took place in February. This year's highlights were:</p>

# %%
soup.find("p").get_text()
# Out:
# "The biggest film awards ceremony took place in February. This year's highlights were:"

# %% [markdown]
# ### 2.5) the find_all() method

# %%
soup.find_all("p")
# Out:
# [<p>The biggest film awards ceremony took place in February. This year's highlights were:</p>,
#  <p>See below the winners of 3 categories.</p>]

# %%
soup.find_all("p")[1]
# Out:
# <p>See below the winners of 3 categories.</p>

# %%
soup.find_all("p")[1].get_text()
# Out:
# 'See below the winners of 3 categories.'

# %%
soup.find_all("h2")
# Out:
# [<h2>Categoria: Melhor Filme</h2>,
#  <h2>Categoria: Melhor Ator</h2>,
#  <h2>Categoria: Melhor Atriz</h2>]

# %% [markdown]
# ### 2.6) Extracting the List of Highlights

# %%
soup.ul.find_all("li")
# Out:
# [<li class="vencedor">Parasita [VENCEDOR]</li>,
#  <li>1917</li>,
#  <li>Era Uma Vez em Hollywood</li>,
#  <li>O Irlandês</li>,
#  <li>Coringa</li>,
#  <li>Pequenas Mulheres</li>,
#  <li>Casamento às Pressas</li>,
#  <li>Ford vs Ferrari</li>,
#  <li>Jojo Rabbit</li>]

# %%
print("Lista de destaques:")

for filme in soup.ul.find_all("li"):
    print(filme.get_text())
# Out:
# Lista de destaques:
# Parasita [VENCEDOR]
# 1917
# Era Uma Vez em Hollywood
# O Irlandês
# Coringa
# Pequenas Mulheres
# Casamento às Pressas
# Ford vs Ferrari
# Jojo Rabbit

# %% [markdown]
# ### Mini-Challenge 1: Extract All Movies from the Best Picture Category

# %%
# "write your answer here"

# %% [markdown]
# ### 2.7)Can the find_all() Method Be Equivalent to the find() Method?

# %%
soup.find_all('p', limit = 1)
# Out:
# [<p>The biggest film awards ceremony took place in February. This year's highlights were:</p>]

# %%
soup.find_all('p')[0]
# Out:
# <p>The biggest film awards ceremony took place in February. This year's highlights were:</p>

# %% [markdown]
# ### 2.8)I Can Also Pass a List of Tags to find_all()

# %%
soup.find_all(["h2", "li"])
# Out:
# [<h2>Categoria: Melhor Filme</h2>,
#  <li class="vencedor">Parasita [VENCEDOR]</li>,
#  <li>1917</li>,
#  <li>Era Uma Vez em Hollywood</li>,
#  <li>O Irlandês</li>,
#  <li>Coringa</li>,
#  <li>Pequenas Mulheres</li>,
#  <li>Casamento às Pressas</li>,
#  <li>Ford vs Ferrari</li>,
#  <li>Jojo Rabbit</li>,
#  <h2>Categoria: Melhor Ator</h2>,
#  <li class="vencedor">Joaquin Phoenix - Coringa [VENCEDOR]</li>,
#  <li>Antonio Banderas - Dor e Glória</li>,
#  <li>Adam Driver - História de um Casamento</li>,
#  <li>Leonardo DiCaprio - Era Uma Vez em Hollywood</li>,
#  <li>Jonathan Pryce - Os Dois Papas</li>,
#  <h2>Categoria: Melhor Atriz</h2>,
#  <li class="vencedor">Renée Zellweger - Judy [VENCEDOR]</li>,
#  <li>Cynthia Erivo - Harriet</li>,
#  <li>Scarlett Johansson - História de um Casamento</li>,
#  <li>Saoirse Ronan - Pequenas Mulheres</li>,
#  <li>Charlize Theron - O Escândalo</li>]

# %% [markdown]
# ### 2.9) Searching for Tags with Specific Text Content

# %%
soup.find_all("li", text="Coringa")
# Out:
# /tmp/ipykernel_757/57135969.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soup.find_all("li", text="Coringa")
# [<li>Coringa</li>]

# %%
soup.find_all("li", text="1917")
# Out:
# /tmp/ipykernel_757/123522690.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soup.find_all("li", text="1917")
# [<li>1917</li>]

# %%
soup.find_all("li", text="O Irlandês")
# Out:
# /tmp/ipykernel_757/1237735690.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soup.find_all("li", text="O Irlandês")
# [<li>O Irlandês</li>]

# %%
import re

# %%
soup.find_all("h2", text=re.compile("^Categoria"))
# Out:
# /tmp/ipykernel_757/2397436340.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soup.find_all("h2", text=re.compile("^Categoria"))
# [<h2>Categoria: Melhor Filme</h2>,
#  <h2>Categoria: Melhor Ator</h2>,
#  <h2>Categoria: Melhor Atriz</h2>]

# %% [markdown]
# ### 2.10) Extracting Elements by Their Attributes

# %%
soup.find_all("ul", {"class": "destaques"})
# Out:
# [<ul class="destaques">
#  <li class="vencedor">Parasita [VENCEDOR]</li>
#  <li>1917</li>
#  <li>Era Uma Vez em Hollywood</li>
#  <li>O Irlandês</li>
#  <li>Coringa</li>
#  <li>Pequenas Mulheres</li>
#  <li>Casamento às Pressas</li>
#  <li>Ford vs Ferrari</li>
#  <li>Jojo Rabbit</li>
#  </ul>,
#  <ul class="destaques">
#  <li class="vencedor">Joaquin Phoenix - Coringa [VENCEDOR]</li>
#  <li>Antonio Banderas - Dor e Glória</li>
#  <li>Adam Driver - História de um Casamento</li>
#  <li>Leonardo DiCaprio - Era Uma Vez em Hollywood</li>
#  <li>Jonathan Pryce - Os Dois Papas</li>
#  </ul>,
#  <ul class="destaques">
#  <li class="vencedor">Renée Zellweger - Judy [VENCEDOR]</li>
#  <li>Cynthia Erivo - Harriet</li>
#  <li>Scarlett Johansson - História de um Casamento</li>
#  <li>Saoirse Ronan - Pequenas Mulheres</li>
#  <li>Charlize Theron - O Escândalo</li>
#  </ul>]

# %%
for item in soup.find_all("ul", {"class": "destaques"}):
    print(item.get_text())
# Out:
# Parasita [VENCEDOR]
# 1917
# Era Uma Vez em Hollywood
# O Irlandês
# Coringa
# Pequenas Mulheres
# Casamento às Pressas
# Ford vs Ferrari
# Jojo Rabbit
#
#
# Joaquin Phoenix - Coringa [VENCEDOR]
# Antonio Banderas - Dor e Glória
# Adam Driver - História de um Casamento
# Leonardo DiCaprio - Era Uma Vez em Hollywood
# Jonathan Pryce - Os Dois Papas
#
#
# Renée Zellweger - Judy [VENCEDOR]
# Cynthia Erivo - Harriet
# Scarlett Johansson - História de um Casamento
# Saoirse Ronan - Pequenas Mulheres
# Charlize Theron - O Escândalo

# %%
soup.find_all("li", {"class": "vencedor"})
# Out:
# [<li class="vencedor">Parasita [VENCEDOR]</li>,
#  <li class="vencedor">Joaquin Phoenix - Coringa [VENCEDOR]</li>,
#  <li class="vencedor">Renée Zellweger - Judy [VENCEDOR]</li>]

# %%
for item in soup.find_all("li", {"class": "vencedor"}):
    print(item.get_text())
# Out:
# Parasita [VENCEDOR]
# Joaquin Phoenix - Coringa [VENCEDOR]
# Renée Zellweger - Judy [VENCEDOR]

# %%
for item in soup.find_all("li", {"class": "vencedor"}):
    print(item.get_text().replace(" [VENCEDOR]", ""))
# Out:
# Parasita
# Joaquin Phoenix - Coringa
# Renée Zellweger - Judy

# %% [markdown]
# ### 2.11) Parents, Siblings, Next, and Previous: Another Way to Navigate HTML
# When the tags we need to search for do not have distinguishing attributes (such as classes or IDs), we can navigate through the HTML structure using relationships like parent, siblings, next, and previous elements.

# %% [markdown]
# #### Parents

# %%
soup.find("li", {"class": "vencedor"}).get_text()
# Out:
# 'Parasita [VENCEDOR]'

# %%
soup.find("li", {"class": "vencedor"}).find_parent()
# Out:
# <ul class="destaques">
# <li class="vencedor">Parasita [VENCEDOR]</li>
# <li>1917</li>
# <li>Era Uma Vez em Hollywood</li>
# <li>O Irlandês</li>
# <li>Coringa</li>
# <li>Pequenas Mulheres</li>
# <li>Casamento às Pressas</li>
# <li>Ford vs Ferrari</li>
# <li>Jojo Rabbit</li>
# </ul>

# %%
soup.find("li", {"class": "vencedor"}).find_parent('div')
# Out:
# <div class="categoria-melhor-filme">
# <h2>Categoria: Melhor Filme</h2>
# <ul class="destaques">
# <li class="vencedor">Parasita [VENCEDOR]</li>
# <li>1917</li>
# <li>Era Uma Vez em Hollywood</li>
# <li>O Irlandês</li>
# <li>Coringa</li>
# <li>Pequenas Mulheres</li>
# <li>Casamento às Pressas</li>
# <li>Ford vs Ferrari</li>
# <li>Jojo Rabbit</li>
# </ul>
# </div>

# %%
soup.find("li", {"class": "vencedor"}).find_parent('div').find('h2').get_text()
# Out:
# 'Categoria: Melhor Filme'

# %% [markdown]
# #### Siblings

# %%
soup.find('h2').get_text()
# Out:
# 'Categoria: Melhor Filme'

# %%
soup.find('h2').find_next_sibling()
# Out:
# <ul class="destaques">
# <li class="vencedor">Parasita [VENCEDOR]</li>
# <li>1917</li>
# <li>Era Uma Vez em Hollywood</li>
# <li>O Irlandês</li>
# <li>Coringa</li>
# <li>Pequenas Mulheres</li>
# <li>Casamento às Pressas</li>
# <li>Ford vs Ferrari</li>
# <li>Jojo Rabbit</li>
# </ul>

# %%
soup.find('div', {'class': 'categoria-melhor-filme'}).find_next_siblings()
# Out:
# [<div class="categoria-melhor-ator">
#  <h2>Categoria: Melhor Ator</h2>
#  <ul class="destaques">
#  <li class="vencedor">Joaquin Phoenix - Coringa [VENCEDOR]</li>
#  <li>Antonio Banderas - Dor e Glória</li>
#  <li>Adam Driver - História de um Casamento</li>
#  <li>Leonardo DiCaprio - Era Uma Vez em Hollywood</li>
#  <li>Jonathan Pryce - Os Dois Papas</li>
#  </ul>
#  </div>,
#  <div class="categoria-melhor-atriz">
#  <h2>Categoria: Melhor Atriz</h2>
#  <ul class="destaques">
#  <li class="vencedor">Renée Zellweger - Judy [VENCEDOR]</li>
#  <li>Cynthia Erivo - Harriet</li>
#  <li>Scarlett Johansson - História de um Casamento</li>
#  <li>Saoirse Ronan - Pequenas Mulheres</li>
#  <li>Charlize Theron - O Escândalo</li>
#  </ul>
#  </div>]

# %%
soup.find('li', {'class': 'vencedor'}).find_next_sibling().get_text()
# Out:
# '1917'

# %%
soup.find('div', {'class': 'categoria-melhor-atriz'}).find_previous_siblings()
# Out:
# [<div class="categoria-melhor-ator">
#  <h2>Categoria: Melhor Ator</h2>
#  <ul class="destaques">
#  <li class="vencedor">Joaquin Phoenix - Coringa [VENCEDOR]</li>
#  <li>Antonio Banderas - Dor e Glória</li>
#  <li>Adam Driver - História de um Casamento</li>
#  <li>Leonardo DiCaprio - Era Uma Vez em Hollywood</li>
#  <li>Jonathan Pryce - Os Dois Papas</li>
#  </ul>
#  </div>,
#  <div class="categoria-melhor-filme">
#  <h2>Categoria: Melhor Filme</h2>
#  <ul class="destaques">
#  <li class="vencedor">Parasita [VENCEDOR]</li>
#  <li>1917</li>
#  <li>Era Uma Vez em Hollywood</li>
#  <li>O Irlandês</li>
#  <li>Coringa</li>
#  <li>Pequenas Mulheres</li>
#  <li>Casamento às Pressas</li>
#  <li>Ford vs Ferrari</li>
#  <li>Jojo Rabbit</li>
#  </ul>
#  </div>,
#  <p>See below the winners of 3 categories.</p>,
#  <p>The biggest film awards ceremony took place in February. This year's highlights were:</p>,
#  <h1>Oscar Awards 2020</h1>]

# %% [markdown]
# #### Next e Previous

# %%
soup.find('div', {'class': 'categoria-melhor-ator'}).find('li', {'class': 'vencedor'}).get_text()
# Out:
# 'Joaquin Phoenix - Coringa [VENCEDOR]'

# %%
soup.find('div', {'class': 'categoria-melhor-ator'}).find('li', {'class': 'vencedor'}).find_next('li').get_text()
# Out:
# 'Antonio Banderas - Dor e Glória'

# %%
soup.find('div', {'class': 'categoria-melhor-ator'}).find('li', {'class': 'vencedor'}).find_previous('li').get_text()
# Out:
# 'Jojo Rabbit'

# %%
soup.find('div', {'class': 'categoria-melhor-ator'}).find('li', {'class': 'vencedor'}).find_all_next('li')
# Out:
# [<li>Antonio Banderas - Dor e Glória</li>,
#  <li>Adam Driver - História de um Casamento</li>,
#  <li>Leonardo DiCaprio - Era Uma Vez em Hollywood</li>,
#  <li>Jonathan Pryce - Os Dois Papas</li>,
#  <li class="vencedor">Renée Zellweger - Judy [VENCEDOR]</li>,
#  <li>Cynthia Erivo - Harriet</li>,
#  <li>Scarlett Johansson - História de um Casamento</li>,
#  <li>Saoirse Ronan - Pequenas Mulheres</li>,
#  <li>Charlize Theron - O Escândalo</li>]

# %%
soup.find('div', {'class': 'categoria-melhor-ator'}).find('li', {'class': 'vencedor'}).find_all_previous('li')
# Out:
# [<li>Jojo Rabbit</li>,
#  <li>Ford vs Ferrari</li>,
#  <li>Casamento às Pressas</li>,
#  <li>Pequenas Mulheres</li>,
#  <li>Coringa</li>,
#  <li>O Irlandês</li>,
#  <li>Era Uma Vez em Hollywood</li>,
#  <li>1917</li>,
#  <li class="vencedor">Parasita [VENCEDOR]</li>]

# %% [markdown]
# ### Mini-Challenge 2: Extract the Names of All Non-Winning Movies

# %% [markdown]
# ## 3) Working with Python Dictionaries and Pandas DataFrames

# %%
import pandas as pd

# %%
soup.find_all("h2", text=re.compile("^Categoria"))
# Out:
# /tmp/ipykernel_757/2397436340.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soup.find_all("h2", text=re.compile("^Categoria"))
# [<h2>Categoria: Melhor Filme</h2>,
#  <h2>Categoria: Melhor Ator</h2>,
#  <h2>Categoria: Melhor Atriz</h2>]

# %%
categorias = soup.find_all("h2", text=re.compile("^Categoria"))
# Out:
# /tmp/ipykernel_757/4158206214.py:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   categorias = soup.find_all("h2", text=re.compile("^Categoria"))

# %%
soup.find_all("li", {"class": "vencedor"})
# Out:
# [<li class="vencedor">Parasita [VENCEDOR]</li>,
#  <li class="vencedor">Joaquin Phoenix - Coringa [VENCEDOR]</li>,
#  <li class="vencedor">Renée Zellweger - Judy [VENCEDOR]</li>]

# %%
vencedores = soup.find_all("li", {"class": "vencedor"})

# %%
vencedores_categorias = {}

# %%
for cat, ven in zip(categorias, vencedores):
    categoria = cat.get_text().replace("Categoria: ", "")
    vencedor = ven.get_text().replace(" [VENCEDOR]", "")

    vencedores_categorias.update({categoria: [vencedor]})

# %%
vencedores_categorias
# Out:
# {'Melhor Filme': ['Parasita'],
#  'Melhor Ator': ['Joaquin Phoenix - Coringa'],
#  'Melhor Atriz': ['Renée Zellweger - Judy']}

# %%
vencedores_categorias_df = pd.DataFrame.from_dict(vencedores_categorias, orient="index", columns=["Vencedores"])

# %%
vencedores_categorias_df
# Out:
#                              Vencedores
# Melhor Filme                   Parasita
# Melhor Ator   Joaquin Phoenix - Coringa
# Melhor Atriz     Renée Zellweger - Judy

# %% [markdown]
# ## 4) Extracting Data from the Web

# %%
from urllib.request import urlopen

# %%
url = 'https://quotes.toscrape.com/'

# %%
response = urlopen(url)

# %%
html_ocean_ws = response.read()

# %%
html_ocean_ws
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n    \n    \n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="change,deep-thoughts,thinking,world" /    > \n            \n            <a class="tag" href="/tag/change/page/1/">change</a>\n            \n            <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>\n            \n            <a class="tag" href="/tag/thinking/page/1/">thinking</a>\n            \n            <a class="tag" href="/tag/world/page/1/">world</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cIt is our choices, Harry, that show what we truly are, far more than our abilities.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">J.K. Rowling</small>\n        <a href="/author/J-K-Rowling">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="abilities,choices" /    > \n            \n            <a class="tag" href="/tag/abilities/page/1/">abilities</a>\n            \n            <a class="tag" href="/tag/choices/page/1/">choices</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThere are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Albert Einstein</small>\n        <a href="/author/Albert-Einstein">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keywords" content="inspirational,life,live,miracle,miracles" /    > \n            \n            <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>\n            \n            <a class="tag" href="/tag/life/page/1/">life</a>\n            \n            <a class="tag" href="/tag/live/page/1/">live</a>\n            \n            <a class="tag" href="/tag/miracle/page/1/">miracle</a>\n            \n            <a class="tag" href="/tag/miracles/page/1/">miracles</a>\n            \n        </div>\n    </div>\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.\xe2\x80\x9d</span>\n        <span>by <small class="author" itemprop="author">Jane Austen</small>\n        <a href="/author/Jane-Austen">(about)</a>\n        </span>\n        <div class="tags">\n            Tags:\n            <meta class="keywords" itemprop="keyw ...

# %%
soup_ocean_ws = BeautifulSoup(html_ocean_ws, 'html.parser')

# %%
soup_ocean_ws
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
# <span>by <small class="author" itemprop="author">J.K. Rowling</small>
# <a href="/author/J-K-Rowling">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="abilities,choices" itemprop="keywords"/>
# <a class="tag" href="/tag/abilities/page/1/">abilities</a>
# <a class="tag" href="/tag/choices/page/1/">choices</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="inspirational,life,live,miracle,miracles" itemprop="keywords"/>
# <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
# <a class="tag" href="/tag/life/page/1/">life</a>
# <a class="tag" href="/tag/live/page/1/">live</a>
# <a class="tag" href="/tag/miracle/page/1/">miracle</a>
# <a class="tag" href="/tag/miracles/page/1/">miracles</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”</span>
# <span>by <small class="author" itemprop="author">Jane Austen</small>
# <a href="/author/Jane-Austen">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="aliteracy,books,classic,humor" itemprop="keywords"/>
# <a class="tag" href="/tag/aliteracy/page/1/">aliteracy</a>
# <a class="tag" href="/tag/books/page/1/">books</a>
# <a class="tag" href="/tag/classic/page/1/">classic</a>
# <a class="tag" href="/tag/humor/page/1/">humor</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”</span>
# <span>by <small class="author" itemprop="author">Marilyn Monroe</small>
# <a href="/author/Marilyn-Monroe">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="be-yourself,inspirational" itemprop="keywords"/>
# <a class="tag" href="/tag/be-yourself/page/1/">be-yourself</a>
# <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“Try not to become a man of success. Rather become a man of value.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="adulthood,success,value" itemprop="keywords"/>
# <a class="tag" href="/tag/adulthood/page/1/">adulthood</a>
# <a class="tag" href="/tag/success/page/1/">success</a>
# <a class="tag" href="/tag/value/page/1/">value</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“It is better to be hated for what you are than to be loved for what you are not.”</span>
# <span>by <small class="author" itemprop="author">André Gide</small>
# <a href="/author/Andre-Gide">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="life,love" itemprop="keywords"/>
# <a class="tag" href="/tag/life/page/1/">life</a>
# <a class="tag" href="/tag/love/page/1/">love</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“I have not failed. I've just found 10,000 ways that won't work.”</span>
# <span>by <small class="author" itemprop="author">Thomas A. Edison</small>
# <a href="/author/Thomas-A-Edison">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="edison,failure,inspirational,paraphrased" itemprop="keywords"/>
# <a class="tag" href="/tag/edison/page/1/">edison</a>
# <a class="tag" href="/tag/failure/page/1/">failure</a>
# <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
# <a class="tag" href="/tag/paraphrased/page/1/">paraphrased</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“A woman is like a tea bag; you never know how strong it is until it's in hot water.”</span>
# <span>by <small class="author" itemprop="author">Eleanor Roosevelt</small>
# <a href="/author/Eleanor-Roosevelt">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="misattributed-eleanor-roosevelt" itemprop="keywords"/>
# <a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">misattributed-eleanor-roosevelt</a>
# </div>
# </div>
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“A day without sunshine is like, you know, night.”</span>
# <span>by <small class="author" itemprop="author">Steve Martin</small>
# <a href="/author/Steve-Martin">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="humor,obvious,simile" itemprop="keywords"/>
# <a class="tag" href="/tag/humor/page/1/">humor</a>
# <a class="tag" href="/tag/obvious/page/1/">obvious</a>
# <a class="tag" href="/tag/simile/page/1/">simile</a>
# </div>
# </div>
# <nav>
# <ul class="pager">
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="col-md-4 tags-box">
# <h2>Top Ten tags</h2>
# <span class="tag-item">
# <a class="tag" href="/tag/love/" style="font-size: 28px">love</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/inspirational/" style="font-size: 26px">inspirational</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/life/" style="font-size: 26px">life</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/humor/" style="font-size: 24px">humor</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/books/" style="font-size: 22px">books</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/reading/" style="font-size: 14px">reading</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/friendship/" style="font-size: 10px">friendship</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/friends/" style="font-size: 8px">friends</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/truth/" style="font-size: 8px">truth</a>
# </span>
# <span class="tag-item">
# <a class="tag" href="/tag/simile/" style="font-size: 6px">simile</a>
# </span>
# </div>
# </div>
# </div>
# <footer class="footer">
# <div class="container">
# <p class="text-muted">
#                 Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
# </p>
# <p class="copyright">
#                 Made with <span class="zyte">❤</span> by <a class="zyte" href="https://www.zyte.com">Zyte</a>
# </p>
# </div>
# </footer>
# </body>
# </html>

# %%
print(soup_ocean_ws.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Albert Einstein
#        </small>
#        <a href="/author/Albert-Einstein">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#        <a class="tag" href="/tag/change/page/1/">
#         change
#        </a>
#        <a class="tag" href="/tag/deep-thoughts/page/1/">
#         deep-thoughts
#        </a>
#        <a class="tag" href="/tag/thinking/page/1/">
#         thinking
#        </a>
#        <a class="tag" href="/tag/world/page/1/">
#         world
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “It is our choices, Harry, that show what we truly are, far more than our abilities.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         J.K. Rowling
#        </small>
#        <a href="/author/J-K-Rowling">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="abilities,choices" itemprop="keywords"/>
#        <a class="tag" href="/tag/abilities/page/1/">
#         abilities
#        </a>
#        <a class="tag" href="/tag/choices/page/1/">
#         choices
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Albert Einstein
#        </small>
#        <a href="/author/Albert-Einstein">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="inspirational,life,live,miracle,miracles" itemprop="keywords"/>
#        <a class="tag" href="/tag/inspirational/page/1/">
#         inspirational
#        </a>
#        <a class="tag" href="/tag/life/page/1/">
#         life
#        </a>
#        <a class="tag" href="/tag/live/page/1/">
#         live
#        </a>
#        <a class="tag" href="/tag/miracle/page/1/">
#         miracle
#        </a>
#        <a class="tag" href="/tag/miracles/page/1/">
#         miracles
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Jane Austen
#        </small>
#        <a href="/author/Jane-Austen">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="aliteracy,books,classic,humor" itemprop="keywords"/>
#        <a class="tag" href="/tag/aliteracy/page/1/">
#         aliteracy
#        </a>
#        <a class="tag" href="/tag/books/page/1/">
#         books
#        </a>
#        <a class="tag" href="/tag/classic/page/1/">
#         classic
#        </a>
#        <a class="tag" href="/tag/humor/page/1/">
#         humor
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Marilyn Monroe
#        </small>
#        <a href="/author/Marilyn-Monroe">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="be-yourself,inspirational" itemprop="keywords"/>
#        <a class="tag" href="/tag/be-yourself/page/1/">
#         be-yourself
#        </a>
#        <a class="tag" href="/tag/inspirational/page/1/">
#         inspirational
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “Try not to become a man of success. Rather become a man of value.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Albert Einstein
#        </small>
#        <a href="/author/Albert-Einstein">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="adulthood,success,value" itemprop="keywords"/>
#        <a class="tag" href="/tag/adulthood/page/1/">
#         adulthood
#        </a>
#        <a class="tag" href="/tag/success/page/1/">
#         success
#        </a>
#        <a class="tag" href="/tag/value/page/1/">
#         value
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “It is better to be hated for what you are than to be loved for what you are not.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         André Gide
#        </small>
#        <a href="/author/Andre-Gide">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="life,love" itemprop="keywords"/>
#        <a class="tag" href="/tag/life/page/1/">
#         life
#        </a>
#        <a class="tag" href="/tag/love/page/1/">
#         love
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “I have not failed. I've just found 10,000 ways that won't work.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Thomas A. Edison
#        </small>
#        <a href="/author/Thomas-A-Edison">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="edison,failure,inspirational,paraphrased" itemprop="keywords"/>
#        <a class="tag" href="/tag/edison/page/1/">
#         edison
#        </a>
#        <a class="tag" href="/tag/failure/page/1/">
#         failure
#        </a>
#        <a class="tag" href="/tag/inspirational/page/1/">
#         inspirational
#        </a>
#        <a class="tag" href="/tag/paraphrased/page/1/">
#         paraphrased
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Eleanor Roosevelt
#        </small>
#        <a href="/author/Eleanor-Roosevelt">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="misattributed-eleanor-roosevelt" itemprop="keywords"/>
#        <a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">
#         misattributed-eleanor-roosevelt
#        </a>
#       </div>
#      </div>
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “A day without sunshine is like, you know, night.”
#       </span>
#       <span>
#        by
#        <small class="author" itemprop="author">
#         Steve Martin
#        </small>
#        <a href="/author/Steve-Martin">
#         (about)
#        </a>
#       </span>
#       <div class="tags">
#        Tags:
#        <meta class="keywords" content="humor,obvious,simile" itemprop="keywords"/>
#        <a class="tag" href="/tag/humor/page/1/">
#         humor
#        </a>
#        <a class="tag" href="/tag/obvious/page/1/">
#         obvious
#        </a>
#        <a class="tag" href="/tag/simile/page/1/">
#         simile
#        </a>
#       </div>
#      </div>
#      <nav>
#       <ul class="pager">
#        <li class="next">
#         <a href="/page/2/">
#          Next
#          <span aria-hidden="true">
#           →
#          </span>
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#     <div class="col-md-4 tags-box">
#      <h2>
#       Top Ten tags
#      </h2>
#      <span class="tag-item">
#       <a class="tag" href="/tag/love/" style="font-size: 28px">
#        love
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/inspirational/" style="font-size: 26px">
#        inspirational
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/life/" style="font-size: 26px">
#        life
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/humor/" style="font-size: 24px">
#        humor
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/books/" style="font-size: 22px">
#        books
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/reading/" style="font-size: 14px">
#        reading
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/friendship/" style="font-size: 10px">
#        friendship
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/friends/" style="font-size: 8px">
#        friends
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/truth/" style="font-size: 8px">
#        truth
#       </a>
#      </span>
#      <span class="tag-item">
#       <a class="tag" href="/tag/simile/" style="font-size: 6px">
#        simile
#       </a>
#      </span>
#     </div>
#    </div>
#   </div>
#   <footer class="footer">
#    <div class="container">
#     <p class="text-muted">
#      Quotes by:
#      <a href="https://www.goodreads.com/quotes">
#       GoodReads.com
#      </a>
#     </p>
#     <p class="copyright">
#      Made with
#      <span class="zyte">
#       ❤
#      </span>
#      by
#      <a class="zyte" href="https://www.zyte.com">
#       Zyte
#      </a>
#     </p>
#    </div>
#   </footer>
#  </body>
# </html>
